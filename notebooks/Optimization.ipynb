# %%
# %matplotlib notebook
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
import math

# %%
def f(x):
    return math.sin(float(x)/5.)*math.exp(float(x)/10.)+5*math.exp(-float(x)/2.)

# %%
minimum = optimize.differential_evolution(f, [(1, 30)])
minimum
# Out:
#      fun: -11.898894665981263
#      jac: array([0.])
#  message: 'Optimization terminated successfully.'
#     nfev: 81
#      nit: 4
#  success: True
#        x: array([25.88019347])

# %%
def h(x):
    return int(f(x))

# %%
X = np.arange(0, 30, 0.1)
plt.plot(X, np.vectorize(h)(X))
plt.plot(X, np.vectorize(f)(X))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
minimumH = optimize.differential_evolution(h, [(1, 30)])
minimumH
# Out:
#      fun: -11.0
#  message: 'Optimization terminated successfully.'
#     nfev: 77
#      nit: 4
#  success: True
#        x: array([25.45805643])
